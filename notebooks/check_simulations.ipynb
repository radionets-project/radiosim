# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "../build/example_data/samp_train_0.h5"
f = h5py.File(path, "r")

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['list', 'x', 'y']>

# %%
plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(f['x'][i][0])

# %%
img = 0
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.imshow(f['y'][img][10]+
           f['y'][img][9]+
           f['y'][img][8]+
           f['y'][img][7]+
           f['y'][img][6]+
           f['y'][img][5]+
           f['y'][img][4]+
           f['y'][img][3]+
           f['y'][img][2]+
           f['y'][img][1]+
           f['y'][img][0]
          )
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(f['y'][img][11])
plt.colorbar();

# %%
plt.plot(f['list'][0, :, 0], 'o-')
plt.xlabel('component')
plt.ylabel('norm. amplitude');

# %%
f['y'].shape
# Out:
# (20, 12, 256, 256)
