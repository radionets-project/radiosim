# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/net/big-tank/POOL/users/apoggenpohl/radionets/data/radiosim/samp_train_0.h5"
f = h5py.File(path, "r")

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['list', 'x', 'y']>

# %%
plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(f['x'][i][0])

# %%
img = 4
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.title('components')
plt.imshow(#f['y'][img][10]+
           #f['y'][img][9]+
           #f['y'][img][8]+
           #f['y'][img][7]+
           #f['y'][img][6]+
           #f['y'][img][5]+
           #f['y'][img][4]+
           f['y'][img][3]+
           #f['y'][img][2]+
           #f['y'][img][1]+
           f['y'][img][0]
          )
plt.colorbar()
plt.subplot(1, 2, 2)
plt.title('background')
plt.imshow(f['y'][img][6])
plt.colorbar();

# %%
plt.plot(f['list'][0, :, 0], 'o-')
plt.xlabel('component')
plt.ylabel('norm. amplitude');

# %%
f['y'].shape
# Out:
# (20, 7, 256, 256)

# %%
f['list'][0]
# Out:
# array([[  0.44503856, 127.15607865, 127.1353123 ,  12.494524  ,
#          12.99816138],
#        [  0.29669237, 135.45134019, 133.4013019 ,  15.09329638,
#          15.02489263],
#        [  0.24015767, 138.81410388, 135.82440083,  13.90863195,
#          18.59111252],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ],
#        [  0.29179203, 118.84266421, 120.8927025 ,  15.09329638,
#          15.02489263],
#        [  0.23619109, 115.47990052, 118.46960356,  13.90863195,
#          18.59111252],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ],
#        [  0.        , 127.1470022 , 127.1470022 ,   0.        ,
#           0.        ]])
